# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
dirty=pd.read_csv('data/Sea_Turtle_Rescue_data/dirty_fixed.csv')
clean=pd.read_csv('data/Sea_Turtle_Rescue_data/cleaned_data_fixed.csv')
test=pd.read_csv('data/Sea_Turtle_Rescue_data/test_data.csv')
submission=pd.read_csv('data/Sea_Turtle_Rescue_data/submission_example.csv')
dirty.head()
# Out:
#       Rescue_ID Date_Caught     Researcher   CaptureSite ForagingGround  \
# 0  1998_RE_0001   4/14/1998  researcher_12      site_110          creek
# 1  1998_RE_0002    7/7/1998   researcher_4  not_recorded          ocean
# 2  1998_RE_0003    8/3/1998            NaN       site_12          creek
# 3  1998_RE_0004    8/7/1998  researcher_12      site_110          creek
# 4  1998_RE_0005   9/25/1998  researcher_17  not_recorded          creek
#
#        CaptureMethod       Fisher   LandingSite    Species   ReleaseSite  \
# 0                net   fisher_619       site_58  species_1       site_80
# 1           longline   fisher_522       site_22  species_1  not_recorded
# 2                net  fisher_1254  not_recorded  species_1      site_109
# 3                net   fisher_360  not_recorded  species_2      site_113
# 4  collected floater   fisher_865        site_8  species_3      site_109
#
#       ...     CCW_cm Weight_Kg      Sex      TurtleCharacteristics    Status  \
# 0     ...       58.5       NaN  Unknown                        NaN  Released
# 1     ...       37.0       NaN      NaN                    1B-1LLS       NaN
# 2     ...       33.0       NaN      NaN                        NaN       NaN
# 3     ...       31.5       NaN      NaN                        NaN       NaN
# 4     ...       63.5       NaN      NaN  Bs on C+ old panga wounds       NaN
#
#    Date_Release        Release_Admiss_Notes  SpecialRemarks PCVNumber  \
# 0     4/14/1998                         NaN             NaN       NaN
# 1           NaN                         NaN             NaN       NaN
# 2           NaN                         NaN             NaN       NaN
# 3           NaN                         NaN             NaN       NaN
# 4           NaN  Found trapped in mangroves             NaN       NaN
#
#   Expenditure
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 26 columns]

# %%
clean.head()
# Out:
#       Rescue_ID Date_Caught     Researcher CaptureSite ForagingGround  \
# 0  1998_RE_0001   4/17/1998  researcher_19    site_110          creek
# 1  1998_RE_0002    7/7/1998  researcher_15     site_15          creek
# 2  1998_RE_0003    8/3/1998   not_recorded     site_12          creek
# 3  1998_RE_0004    8/7/1998  researcher_19    site_110          creek
# 4  1998_RE_0005   9/25/1998  researcher_17      site_8          creek
#
#        CaptureMethod       Fisher   LandingSite    Species   ReleaseSite  \
# 0                net   fisher_619       site_58  species_1       site_80
# 1           longline   fisher_522       site_22  species_1  not_recorded
# 2       not_recorded  fisher_1254  not_recorded  species_1      site_109
# 3       not_recorded   fisher_360  not_recorded  species_2      site_108
# 4  collected floater   fisher_865        site_8  species_3      site_121
#
#       ...     CCW_cm Weight_Kg      Sex            TurtleCharacteristics  \
# 0     ...      58.42       NaN  Unknown                              NaN
# 1     ...      36.83       NaN  Unknown                          1B-1LLS
# 2     ...      33.00       NaN  Unknown                              NaN
# 3     ...      31.75       NaN  Unknown  There was pillings on carapace.
# 4     ...      63.50       NaN  Unknown        Bs on C+ old panga wounds
#
#      Status  Date_Release        Release_Admiss_Notes  SpecialRemarks  \
# 0  Released     4/17/1998                         NaN             NaN
# 1       NaN           NaN                         NaN             NaN
# 2  Released      8/3/1998                         NaN             NaN
# 3  Released      8/7/1998                         NaN             NaN
# 4  Released     9/25/1998  Found trapped in mangroves             NaN
#
#   PCVNumber Expenditure
# 0       NaN         NaN
# 1       NaN         NaN
# 2       NaN         NaN
# 3       NaN         NaN
# 4       NaN         NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Build the train and test data

# %% [markdown]
# #### train

# %%
columns=[]
res=[]
before=[]
after=[]
year=[]
column_name=[]
for rescue_id in clean['Rescue_ID']:
    columns.extend([rescue_id+" x "+c for c in  clean.columns[1:]])
    year.extend([rescue_id[:4]]*25)
    column_name.extend([c for c in  clean.columns[1:]])
for i in range(clean.shape[0]):
    for j in range(1,clean.shape[1]):
        before.append(dirty.iloc[i,j])
        after.append(clean.iloc[i,j])
        res.append(int(dirty.iloc[i,j]==clean.iloc[i,j]))
        
train_df=pd.DataFrame.from_dict({'ID':columns,'before':before,'after':after,'column_name':column_name,'year':year,'error':res})
train_df.head()
# Out:
#                               ID         before          after  \
# 0     1998_RE_0001 x Date_Caught      4/14/1998      4/17/1998
# 1      1998_RE_0001 x Researcher  researcher_12  researcher_19
# 2     1998_RE_0001 x CaptureSite       site_110       site_110
# 3  1998_RE_0001 x ForagingGround          creek          creek
# 4   1998_RE_0001 x CaptureMethod            net            net
#
#       column_name  year  error
# 0     Date_Caught  1998      0
# 1      Researcher  1998      0
# 2     CaptureSite  1998      1
# 3  ForagingGround  1998      1
# 4   CaptureMethod  1998      1

# %% [markdown]
# #### test

# %%
columns=[]
res=[]
before=[]
year=[]
column_name=[]
for rescue_id in test['Rescue_ID']:
    columns.extend([rescue_id+" x "+c for c in  test.columns[1:]])
    year.extend([rescue_id[:4]]*25)
    column_name.extend([c for c in  clean.columns[1:]])
res=[0]*(len(columns))
for i in range(test.shape[0]):
    for j in range(1,test.shape[1]):
        before.append(test.iloc[i,j])
        
test_df=pd.DataFrame.from_dict({'ID':columns,'before':before,'column_name':column_name,'year':year,'error':res})
test_df.head()
# Out:
#                               ID        before     column_name  year  error
# 0     2011_RE_0001 x Date_Caught      1/1/2011     Date_Caught  2011      0
# 1      2011_RE_0001 x Researcher  researcher_4      Researcher  2011      0
# 2     2011_RE_0001 x CaptureSite       site_38     CaptureSite  2011      0
# 3  2011_RE_0001 x ForagingGround         ocean  ForagingGround  2011      0
# 4   2011_RE_0001 x CaptureMethod           net   CaptureMethod  2011      0

# %% [markdown]
# ### Data exploration

# %% [markdown]
# ### the distribution of the data by year

# %%
sns.factorplot("year", data=train_df, aspect=2,  hue='error',
                       kind="count", color='steelblue')
# Out:
# /home/ubuntu/anaconda3/envs/hamza/lib/python3.6/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# #### almost equal probab of error

# %%
g=sns.factorplot("column_name", data=train_df, aspect=2,  hue='error',
                       kind="count", color='steelblue')
g.set_xticklabels(rotation=80)
# Out:
# /home/ubuntu/anaconda3/envs/hamza/lib/python3.6/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
np.unique(train_df.column_name.values)
# Out:
# array(['CCL_cm', 'CCW_cm', 'CaptureMethod', 'CaptureSite', 'Date_Caught',
#        'Date_Release', 'Expenditure', 'Fisher', 'ForagingGround',
#        'LandingSite', 'Lost_Tags', 'PCVNumber', 'ReleaseSite',
#        'Release_Admiss_Notes', 'Researcher', 'Sex', 'SpecialRemarks',
#        'Species', 'Status', 'T_Number', 'Tag_1', 'Tag_2', 'Tag_3',
#        'TurtleCharacteristics', 'Weight_Kg'], dtype=object)

# %% [markdown]
# ### Dummy submit again

# %%
test_df.head()
# Out:
#                               ID        before     column_name  year  error
# 0     2011_RE_0001 x Date_Caught      1/1/2011     Date_Caught  2011      0
# 1      2011_RE_0001 x Researcher  researcher_4      Researcher  2011      0
# 2     2011_RE_0001 x CaptureSite       site_38     CaptureSite  2011      0
# 3  2011_RE_0001 x ForagingGround         ocean  ForagingGround  2011      0
# 4   2011_RE_0001 x CaptureMethod           net   CaptureMethod  2011      0

# %%
submit=test_df.copy()
submit['error']=0
submit.loc[submit['column_name'] =='Researcher','error']=1
submit.loc[submit['column_name'] =='Species','error']=1
submit.loc[submit['column_name'] =='Tag_1','error']=1
submit.drop(columns=['column_name','before','year']).to_csv('dummy_submit.csv',header=True,index=False)
